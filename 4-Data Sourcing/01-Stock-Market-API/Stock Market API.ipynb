# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
import requests

url = "http://iex.lewagon.com/stable/stock/aapl/chart/3m"
api_data = requests.get(url).json()

apple_stock_df = pd.DataFrame(api_data)
apple_stock_df
# Out:
#           date    open   close    high     low     volume   uOpen  uClose  \
# 0   2020-07-10   95.34   95.92   95.98   94.71   90257320  381.34  383.68
# 1   2020-07-13   97.27   95.48   99.96   95.26  191649140  389.06  381.91
# 2   2020-07-14   94.84   97.06   97.26   93.88  170989364  379.36  388.23
# 3   2020-07-15   98.99   97.73   99.25   96.49  153197932  395.96  390.90
# 4   2020-07-16   96.56   96.52   97.41   95.91  110577672  386.25  386.09
# ..         ...     ...     ...     ...     ...        ...     ...     ...
# 61  2020-10-06  115.70  113.16  116.12  112.25  161498212  115.70  113.16
# 62  2020-10-07  114.62  115.08  115.55  114.13   96848985  114.62  115.08
# 63  2020-10-08  116.25  114.97  116.40  114.59   83477153  116.25  114.97
# 64  2020-10-09  115.28  116.97  117.00  114.92  100506865  115.28  116.97
# 65  2020-10-12  120.06  124.40  125.18  119.28  240226769  120.06  124.40
#
#      uHigh    uLow    uVolume  change  changePercent       label  \
# 0   383.92  378.82   22564330    0.00         0.0000  Jul 10, 20
# 1   399.82  381.03   47912285   -0.44        -0.4613  Jul 13, 20
# 2   389.02  375.51   42747341    1.58         1.6548  Jul 14, 20
# 3   396.99  385.96   38299483    0.67         0.6877  Jul 15, 20
# 4   389.62  383.62   27644418   -1.20        -1.2305  Jul 16, 20
# ..     ...     ...        ...     ...            ...         ...
# 61  116.12  112.25  161498212   -3.34        -2.8670   Oct 6, 20
# 62  115.55  114.13   96848985    1.92         1.6967   Oct 7, 20
# 63  116.40  114.59   83477153   -0.11        -0.0956   Oct 8, 20
# 64  117.00  114.92  100506865    2.00         1.7396   Oct 9, 20
# 65  125.18  119.28  240226769    7.43         5.9700  Oct 12, 20
#
#     changeOverTime
# 0         0.000000
# 1        -0.004613
# 2         0.011859
# 3         0.018818
# 4         0.006281
# ..             ...
# 61        0.179733
# 62        0.199750
# 63        0.198603
# 64        0.219454
# 65        0.000000
#
# [66 rows x 15 columns]

# %%
#Convert the date column to a datetime object
apple_stock_df.date = pd.to_datetime(apple_stock_df.date, format="%Y-%m-%d")

# %%
apple_stock_df.head()
# Out:
#         date   open  close   high    low     volume   uOpen  uClose   uHigh  \
# 0 2020-07-10  95.34  95.92  95.98  94.71   90257320  381.34  383.68  383.92
# 1 2020-07-13  97.27  95.48  99.96  95.26  191649140  389.06  381.91  399.82
# 2 2020-07-14  94.84  97.06  97.26  93.88  170989364  379.36  388.23  389.02
# 3 2020-07-15  98.99  97.73  99.25  96.49  153197932  395.96  390.90  396.99
# 4 2020-07-16  96.56  96.52  97.41  95.91  110577672  386.25  386.09  389.62
#
#      uLow   uVolume  change  changePercent       label  changeOverTime
# 0  378.82  22564330    0.00         0.0000  Jul 10, 20        0.000000
# 1  381.03  47912285   -0.44        -0.4613  Jul 13, 20       -0.004613
# 2  375.51  42747341    1.58         1.6548  Jul 14, 20        0.011859
# 3  385.96  38299483    0.67         0.6877  Jul 15, 20        0.018818
# 4  383.62  27644418   -1.20        -1.2305  Jul 16, 20        0.006281

# %%
apple_stock_df.date.describe
# Out:
# <bound method NDFrame.describe of 0    2020-07-10
# 1    2020-07-13
# 2    2020-07-14
# 3    2020-07-15
# 4    2020-07-16
#         ...
# 61   2020-10-06
# 62   2020-10-07
# 63   2020-10-08
# 64   2020-10-09
# 65   2020-10-12
# Name: date, Length: 66, dtype: datetime64[ns]>

# %%
#Set the date column as the index

apple_stock_df.set_index('date', inplace=True)

# idem apple_stock_df = apple_stock_df.set_index('date')

apple_stock_df.head()
# Out:
#              open  close   high    low     volume   uOpen  uClose   uHigh  \
# date
# 2020-07-10  95.34  95.92  95.98  94.71   90257320  381.34  383.68  383.92
# 2020-07-13  97.27  95.48  99.96  95.26  191649140  389.06  381.91  399.82
# 2020-07-14  94.84  97.06  97.26  93.88  170989364  379.36  388.23  389.02
# 2020-07-15  98.99  97.73  99.25  96.49  153197932  395.96  390.90  396.99
# 2020-07-16  96.56  96.52  97.41  95.91  110577672  386.25  386.09  389.62
#
#               uLow   uVolume  change  changePercent       label  \
# date
# 2020-07-10  378.82  22564330    0.00         0.0000  Jul 10, 20
# 2020-07-13  381.03  47912285   -0.44        -0.4613  Jul 13, 20
# 2020-07-14  375.51  42747341    1.58         1.6548  Jul 14, 20
# 2020-07-15  385.96  38299483    0.67         0.6877  Jul 15, 20
# 2020-07-16  383.62  27644418   -1.20        -1.2305  Jul 16, 20
#
#             changeOverTime
# date
# 2020-07-10        0.000000
# 2020-07-13       -0.004613
# 2020-07-14        0.011859
# 2020-07-15        0.018818
# 2020-07-16        0.006281

# %%
apple_stock_df.close.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#figsize in inches (width, height)!

apple_stock_df[['open', 'close', 'high', 'low']].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# **What is the URL for the:**
#
# Amazon stock prices since last year?
# Facebook market cap?
# Apple research and development spendings quarterly?
# Last news about Tesla?
# Performance of the ‘Energy’ sector?

# %%
url2 = "http://iex.lewagon.com/stable/stock/amzn/chart/1y"
api_data = requests.get(url2).json()

amzn_stock_df = pd.DataFrame(api_data)
amzn_stock_df.date = pd.to_datetime(amzn_stock_df.date, format="%Y-%m-%d")
amzn_stock_df.set_index('date', inplace=True)
amzn_stock_df.close.plot(figsize=(16,6))

# %%
url3 = "http://iex.lewagon.com/stable/stock/fb/quote/marketCap"
fb_mkt_cap = requests.get(url3).json()

fb_mkt_cap
# Out:
# 785560379981

# %%
url4 = "http://iex.lewagon.com/stable/stock/aapl/income/"
appl_financials = requests.get(url4).json()

appl_financials['income'][0]['researchAndDevelopment']

# appl_financials = pd.DataFrame(requests.get(url4).json()['income'])
# appl_financials[['researchAndDevelopment']]
# Out:
# 4758000000

# %%
url5 = "http://iex.lewagon.com/stable/stock/tsla/news/last/"
tsla_news = requests.get(url5).json()

tsla_news
# Out:
# [{'datetime': 1602609316000,
#   'headline': 'Tesla Energy considers Poland as oil companies invest in renewables',
#   'source': 'Teslarati',
#   'url': 'https://cloud.iexapis.com/v1/news/article/c47fabf5-27cb-4739-9a0d-6cc58af74b8e',
#   'summary': 'Tesla posted hiring advertisements for Field Service Technicians in Warsaw, Poland, as the company begins a push to expand its energy business into Europe. Interestingly, the push into the country from Tesla comes on the heels of Polish oil companies offering a sizeable $1 billion investment into renewable energy sources. Tesla’s push into Poland began …',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/c47fabf5-27cb-4739-9a0d-6cc58af74b8e',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602607920000,
#   'headline': 'Tesla cuts Model S prices by $3,000 in the US - Roadshow',
#   'source': 'CNET',
#   'url': 'https://cloud.iexapis.com/v1/news/article/690187bf-d06f-47d4-a967-184e2acf4f73',
#   'summary': 'The slice applies to both the Long Range Plus and Performance variants.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/690187bf-d06f-47d4-a967-184e2acf4f73',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602604969000,
#   'headline': 'Tesla-powered Slovenian company ups the ante with new Megapack installation',
#   'source': 'Teslarati',
#   'url': 'https://cloud.iexapis.com/v1/news/article/87fa3573-0fc0-48bd-8526-6a8163c4587d',
#   'summary': 'A Tesla-powered company in the European country of Slovenia has increased its sustainable energy project by adding Tesla Megapacks to its already existing infrastructure of Powerpacks. In 2019, NGEN, a Slovenian energy system solutions company, became the first country in the Balkin Peninsula to install a grid-scale battery storage unit. It consisted of 126 Tesla …',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/87fa3573-0fc0-48bd-8526-6a8163c4587d',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602602922000,
#   'headline': 'Apple Short Interest Jumps By $1.3B Ahead Of iPhone Event',
#   'source': 'Benzinga',
#   'url': 'https://cloud.iexapis.com/v1/news/article/7e4a5c85-3ad7-43dc-8870-7147fd5420eb',
#   'summary': 'On Tuesday, Apple, Inc (NASDAQ: AAPL ) shares ticked lower by about 0.5% after the stock gained 6% on Monday in anticipation of the big iPhone 12 event. Apple investors have high hopes for the first 5G-compatible iPhone, but short sellers are betting the sell-the-news drop is just getting started. S3 Partners analyst Ihor Dusaniwsky says Apple’s short sellers have added $1.3 billion to their bearish bets in the month leading up to Tuesday’s iPhone event. Apple now has $10.8 billion in total short interest, trailing just Tesla Inc (NASDAQ: TSLA ) with $25.4 billion and Alibaba Group Holding Ltd - ADR (NYSE: BABA ) with $14.3 billion on the list of the most heavily shorted stocks in … Full story available on Benzinga.com',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/7e4a5c85-3ad7-43dc-8870-7147fd5420eb',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602598279000,
#   'headline': '14 Things to Know About the Latest Tesla Model S Price Drop',
#   'source': 'InvestorPlace',
#   'url': 'https://cloud.iexapis.com/v1/news/article/e4b5afac-7e22-450f-b715-f7058c239bd0',
#   'summary': "A price drop is in effect for Tesla's (TSLA) Model S electric vehicle but it doesn't bring it anywhere close to its cheaper offerings.",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/e4b5afac-7e22-450f-b715-f7058c239bd0',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602594967000,
#   'headline': "Tesla doesn't want to deal with press at all; Musk sets dangerous precedent",
#   'source': 'IBTimes India',
#   'url': 'https://cloud.iexapis.com/v1/news/article/12c1a2d3-b89d-4172-a0e1-31ffe7fe484d',
#   'summary': "Tesla has set a dangerous precedent by dissolving its global PR team, leaving journalists with no way of contacting the world's most valuable automobile brand except for tweeting to Elon Musk or sending a DM to Tesla Twitter.",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/12c1a2d3-b89d-4172-a0e1-31ffe7fe484d',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602594185000,
#   'headline': 'Tesla : cuts prices of Model S in United States, China | MarketScreener',
#   'source': 'MarketScreener',
#   'url': 'https://cloud.iexapis.com/v1/news/article/d3824ab8-0c38-47af-b17e-7588e27ac44d',
#   'summary': 'Tesla Inc said on Tuesday it cut the price of its Model S Long Range sedan by 4% in the United States, days after the electric-car maker reported record quarterly deliveries…. | October 13, 2020',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/d3824ab8-0c38-47af-b17e-7588e27ac44d',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602588775000,
#   'headline': 'Elon Musk Denies Reports Of Bitcoin ATM At Nevada Gigafactory',
#   'source': 'IBTimes',
#   'url': 'https://cloud.iexapis.com/v1/news/article/a65859ea-e325-4c2b-aea5-991af916ab83',
#   'summary': 'Tesla CEO said reports of a Bitcoin ATM inside one of its facilities are "inaccurate".',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/a65859ea-e325-4c2b-aea5-991af916ab83',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602587801000,
#   'headline': 'Tesla drops prices on Model S (NASDAQ:TSLA)',
#   'source': 'Seeking Alpha',
#   'url': 'https://cloud.iexapis.com/v1/news/article/18bf550f-5970-490d-b0a4-20474e053b1c',
#   'summary': 'As was largely anticipated, Tesla (NASDAQ:TSLA) officially drops the price of both versions of the Model S available for order on its website by $3K. The L',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/18bf550f-5970-490d-b0a4-20474e053b1c',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1602587160000,
#   'headline': 'Forget Tesla! Intuitive Surgical Is a Better Growth Stock',
#   'source': 'The Motley Fool',
#   'url': 'https://cloud.iexapis.com/v1/news/article/8b120558-1065-48f5-b307-f08bdf2526e4',
#   'summary': "Investors can't go wrong with either company, but the robotic surgery leader looks like the better pick.",
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/8b120558-1065-48f5-b307-f08bdf2526e4',
#   'lang': 'en',
#   'hasPaywall': False}]

# %%
url6 = "http://iex.lewagon.com/stable/stock/market/sector-performance"
sector_performances = pd.DataFrame(requests.get(url6).json())

sector_performances[sector_performances['name']=='Energy']
# Out:
#      type    name  performance    lastUpdated
# 9  sector  Energy       0.0026  1602532800207

# %%
stocks = ['goog', 'fb', 'amzn', 'aapl', 'meli']
stocks_data = pd.DataFrame(columns=['date']+stocks)
for stock in stocks:
    url = f"http://iex.lewagon.com/stable/stock/{stock}/chart/1y"
    api_data = pd.DataFrame(requests.get(url).json())
    stocks_data[['date', stock]] = api_data[['date', 'close']]
    
stocks_data.head()
# Out:
#          date     goog      fb     amzn   aapl    meli
# 0  2019-10-10  1208.67  180.03  1720.26  57.52  542.41
# 1  2019-10-11  1215.45  184.19  1731.92  59.05  554.21
# 2  2019-10-14  1217.14  183.28  1736.43  58.97  555.58
# 3  2019-10-15  1243.01  188.89  1767.38  58.83  566.55
# 4  2019-10-16  1243.64  189.55  1777.43  58.59  548.98

# %%
stocks_data.date = pd.to_datetime(stocks_data.date, format="%Y-%m-%d")
stocks_data.set_index('date', inplace=True)
stocks_data.plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#normalization technique
def normalization(series):
    return series/series[0]

stocks_data_normalized = stocks_data.apply(normalization, axis=0)

print(stocks_data_normalized.head())
stocks_data_normalized.plot(figsize=(15,7))
# Out:
#                 goog        fb      amzn      aapl      meli
# date
# 2019-10-10  1.000000  1.000000  1.000000  1.000000  1.000000
# 2019-10-11  1.005609  1.023107  1.006778  1.026599  1.021755
# 2019-10-14  1.007008  1.018053  1.009400  1.025209  1.024281
# 2019-10-15  1.028411  1.049214  1.027391  1.022775  1.044505
# 2019-10-16  1.028933  1.052880  1.033233  1.018602  1.012113
# <AxesSubplot:xlabel='date'>
